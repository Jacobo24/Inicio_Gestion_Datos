# %%
import pandas as pd

df = pd.read_csv('Tabla_Cliente.csv')

# %%
for i in df.columns:
    if df[i].dtype == 'object':
        # Replace commas with dots in string columns
        df[i] = df[i].str.replace(',', '.')
        if df[i].str.contains('.').any():
            try:
                # Convert to float if possible
                df[i] = df[i].astype(float)
            except ValueError:
                # If conversion fails, keep as string
                pass

# %%
df
# Out:
#        Customer_ID  Edad  churn_estimado  retencion_estimado  CLTV_1_anio  \
# 0            63910    42        0.000000            1.000000  2646.878480
# 1            43014    51        0.000000            1.000000   318.990661
# 2            47322    30        0.742781            0.257219   -58.492058
# 3            41053    30        0.000000            1.000000  6734.093440
# 4            88728    47        0.000000            1.000000  1602.243013
# ...            ...   ...             ...                 ...          ...
# 44048        97110    44        0.000000            1.000000  1136.074744
# 44049        95854    53        0.000000            1.000000  2088.084112
# 44050        24049    47        0.000000            1.000000  4171.261682
# 44051        93893    35        0.000000            1.000000  2017.822494
# 44052        52759    44        0.000000            1.000000  2223.509373
#
#        CLTV_2_anios  CLTV_3_anios  CLTV_4_anios  CLTV_5_anios
# 0       5131.229333   7433.798417   9595.752595  11618.724004
# 1        618.394176    895.890117   1156.439741   1400.239746
# 2        -72.613488    -75.980008    -76.793060    -76.988748
# 3      13054.689914  18912.803719  24413.170116  29559.941531
# 4       3106.102684   4499.923842   5808.626151   7033.197597
# ...             ...           ...           ...           ...
# 44048   2202.390512   3190.683175   4118.622087   4986.907784
# 44049   4047.952533   5864.415948   7569.950299   9165.843156
# 44050   8086.393261  11715.051798  15122.112866  18310.148581
# 44051   3911.743606   5667.085125   7315.230216   8857.423122
# 44052   4310.487469   6244.759851   8060.908728   9760.305177
#
# [44053 rows x 9 columns]
