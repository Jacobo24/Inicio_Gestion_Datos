# %%
import pandas as pd

df = pd.read_csv('Tabla_Cliente.csv')

# %%
for i in df.columns:
    if df[i].dtype == 'object':
        # Replace commas with dots in string columns
        df[i] = df[i].str.replace(',', '.')
        if df[i].str.contains('.').any():
            try:
                # Convert to float if possible
                df[i] = df[i].astype(float)
            except ValueError:
                # If conversion fails, keep as string
                pass

# %%
df
# Out:
#        Customer_ID  Edad  churn_estimado  retencion_estimado  CLTV_1_anio  \
# 0            63910    42        0.000000            1.000000  2646.878480
# 1            43014    51        0.000000            1.000000   318.990661
# 2            41053    30        0.000000            1.000000  6734.093440
# 3            15706    41        0.170244            0.829756   146.068065
# 4            87506    45        1.000000            0.000000     0.000000
# ...            ...   ...             ...                 ...          ...
# 44048        74992    30        1.000000            0.000000     0.000000
# 44049        87533    58        0.100929            0.899071  2206.905059
# 44050        95854    53        0.000000            1.000000  2088.084112
# 44051        24049    47        0.000000            1.000000  4171.261682
# 44052        52759    44        0.000000            1.000000  2223.509373
#
#        CLTV_2_anios  CLTV_3_anios  CLTV_4_anios  CLTV_5_anios
# 0       5131.229333   7433.798417   9595.752595  11618.724004
# 1        618.394176    895.890117   1156.439741   1400.239746
# 2      13054.689914  18912.803719  24413.170116  29559.941531
# 3        259.826751    347.311970    415.470287    468.389393
# 4          0.000000      0.000000      0.000000      0.000000
# ...             ...           ...           ...           ...
# 44048      0.000000      0.000000      0.000000      0.000000
# 44049   4069.235478   5621.088683   6931.110758   8033.198151
# 44050   4047.952533   5864.415948   7569.950299   9165.843156
# 44051   8086.393261  11715.051798  15122.112866  18310.148581
# 44052   4310.487469   6244.759851   8060.908728   9760.305177
#
# [44053 rows x 9 columns]
